# %% [markdown]
# ### VIX (CBOE Volatility Index) is a popular measure of the stock market's expectation of volatility implied by S&P 500 index options. This data will be used to determine if volatility in the markets impacts price of bitcoin.

# %%
#Import required packages 
import numpy as np
import pandas as pd
import pandas_profiling
from datetime import datetime
import pickle

# %%
vix_volatility_hourly_history_df = pd.read_csv('./data/vix_volatility_hourly_history.csv')

# %%
vix_volatility_hourly_history_df['date'] = vix_volatility_hourly_history_df['Local time'].astype(str).str[5:]

# %%
vix_volatility_hourly_history_df['date_1'] = vix_volatility_hourly_history_df['Local time'].astype(str).str[0:2]

# %%
vix_volatility_hourly_history_df['date_2'] = vix_volatility_hourly_history_df['Local time'].astype(str).str[3:5]

# %%
vix_volatility_hourly_history_df['local_time'] = vix_volatility_hourly_history_df['date_2'] + '.' + vix_volatility_hourly_history_df['date_1'] + vix_volatility_hourly_history_df['date']
vix_volatility_hourly_history_df.drop(['date', 'date_1', 'date_2'], axis = 1, inplace = True)

# %%
vix_volatility_hourly_history_df.head(2)
# Out:
#                          Local time   Open   High    Low  Close  Volume  \
# 0  26.01.2017 00:00:00.000 GMT-0800  19.14  19.14  19.14  19.14     0.0
# 1  26.01.2017 01:00:00.000 GMT-0800  19.14  19.14  19.14  19.14     0.0
#
#                          local_time
# 0  01.26.2017 00:00:00.000 GMT-0800
# 1  01.26.2017 01:00:00.000 GMT-0800

# %%
vix_volatility_hourly_history_df['local_time'] = pd.to_datetime(vix_volatility_hourly_history_df['local_time'], utc = True)

# %%
pandas_profiling.ProfileReport(vix_volatility_hourly_history_df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>20735 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.1 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>56.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Close"><code>Close</code></a> is highly correlated with <a href="#pp_var_Low"><code>Low</code></a> (ρ = 0.99984) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_High"><code>High</code></a> is highly correlated with <a href="#pp_var_Open"><code>Open</code></a> (ρ = 0.9998) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Low"><code>Low</code></a> is highly correlated with <a href="#pp_var_High"><code>High</code></a> (ρ = 0.99955) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Volume"><code>Volume</code></a> is highly skewed (γ1 = 31.464)  <span class="label label-info">Skewed</span></li><li><a href="#pp_var_Volume"><code>Volume</code></a> has 16594 / 80.0% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_local_time"><code>local_time</code></a> has a high cardinality: 20731 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow ignore">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Close"><s>Close</s><br/>

# %%
vix_volatility_hourly_history_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20735 entries, 0 to 20734
# Data columns (total 7 columns):
# Local time    20735 non-null object
# Open          20735 non-null float64
# High          20735 non-null float64
# Low           20735 non-null float64
# Close         20735 non-null float64
# Volume        20735 non-null float64
# local_time    20735 non-null datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(5), object(1)
# memory usage: 1.1+ MB

# %%
vix_volatility_hourly_history_df['local_time'].value_counts()
# Out:
# 2018-11-03 17:00:00+00:00    2
# 2017-11-04 18:00:00+00:00    2
# 2017-11-04 17:00:00+00:00    2
# 2018-11-03 18:00:00+00:00    2
# 2017-09-18 20:00:00+00:00    1
# 2017-07-28 00:00:00+00:00    1
# 2018-07-23 14:00:00+00:00    1
# 2019-05-11 23:00:00+00:00    1
# 2018-07-11 08:00:00+00:00    1
# 2017-04-23 17:00:00+00:00    1
# 2018-12-18 13:00:00+00:00    1
# 2018-12-26 18:00:00+00:00    1
# 2018-12-08 03:00:00+00:00    1
# 2017-10-08 03:00:00+00:00    1
# 2017-11-09 16:00:00+00:00    1
# 2018-08-07 23:00:00+00:00    1
# 2017-04-05 19:00:00+00:00    1
# 2018-12-22 07:00:00+00:00    1
# 2018-11-07 04:00:00+00:00    1
# 2017-07-10 02:00:00+00:00    1
# 2017-10-02 22:00:00+00:00    1
# 2017-08-14 22:00:00+00:00    1
# 2018-06-21 10:00:00+00:00    1
# 2017-12-09 10:00:00+00:00    1
# 2018-11-01 05:00:00+00:00    1
# 2018-04-08 13:00:00+00:00    1
# 2019-03-01 08:00:00+00:00    1
# 2017-11-23 14:00:00+00:00    1
# 2017-05-29 13:00:00+00:00    1
# 2018-02-16 22:00:00+00:00    1
#                             ..
# 2017-09-14 16:00:00+00:00    1
# 2018-07-02 07:00:00+00:00    1
# 2017-02-12 03:00:00+00:00    1
# 2018-04-11 10:00:00+00:00    1
# 2018-04-07 10:00:00+00:00    1
# 2018-08-12 00:00:00+00:00    1
# 2018-01-09 13:00:00+00:00    1
# 2017-02-03 04:00:00+00:00    1
# 2017-08-30 16:00:00+00:00    1
# 2018-07-19 13:00:00+00:00    1
# 2018-05-02 00:00:00+00:00    1
# 2017-04-15 20:00:00+00:00    1
# 2018-12-14 10:00:00+00:00    1
# 2018-12-31 10:00:00+00:00    1
# 2018-10-30 16:00:00+00:00    1
# 2017-04-06 21:00:00+00:00    1
# 2018-12-24 22:00:00+00:00    1
# 2018-09-19 17:00:00+00:00    1
# 2017-12-20 16:00:00+00:00    1
# 2017-03-28 22:00:00+00:00    1
# 2018-06-09 11:00:00+00:00    1
# 2017-03-11 00:00:00+00:00    1
# 2018-12-16 10:00:00+00:00    1
# 2017-03-19 23:00:00+00:00    1
# 2017-09-30 13:00:00+00:00    1
# 2019-02-19 12:00:00+00:00    1
# 2018-07-09 22:00:00+00:00    1
# 2017-11-16 22:00:00+00:00    1
# 2018-01-04 21:00:00+00:00    1
# 2019-01-15 12:00:00+00:00    1
# Name: local_time, Length: 20731, dtype: int64

# %%
vix_volatility_hourly_history_df[vix_volatility_hourly_history_df.local_time == '2018-11-03 17:00:00+00:00']
# Out:
#                              Local time    Open    High     Low   Close  \
# 15527  04.11.2018 00:00:00.000 GMT-0700  36.627  36.627  36.627  36.627
# 15529  04.11.2018 01:00:00.000 GMT-0800  36.627  36.627  36.627  36.627
#
#        Volume                local_time
# 15527     0.0 2018-11-03 17:00:00+00:00
# 15529     0.0 2018-11-03 17:00:00+00:00

# %%
vix_volatility_hourly_history_df[15526:15531]
# Out:
#                              Local time    Open    High     Low   Close  \
# 15526  03.11.2018 23:00:00.000 GMT-0700  36.627  36.627  36.627  36.627
# 15527  04.11.2018 00:00:00.000 GMT-0700  36.627  36.627  36.627  36.627
# 15528  04.11.2018 01:00:00.000 GMT-0700  36.627  36.627  36.627  36.627
# 15529  04.11.2018 01:00:00.000 GMT-0800  36.627  36.627  36.627  36.627
# 15530  04.11.2018 02:00:00.000 GMT-0800  36.627  36.627  36.627  36.627
#
#        Volume                local_time
# 15526     0.0 2018-11-03 16:00:00+00:00
# 15527     0.0 2018-11-03 17:00:00+00:00
# 15528     0.0 2018-11-03 18:00:00+00:00
# 15529     0.0 2018-11-03 17:00:00+00:00
# 15530     0.0 2018-11-03 18:00:00+00:00

# %%
vix_volatility_hourly_history_df.drop(15529, inplace = True)

# %%
vix_volatility_hourly_history_df[15526:15531]
# Out:
#                              Local time    Open    High     Low   Close  \
# 15526  03.11.2018 23:00:00.000 GMT-0700  36.627  36.627  36.627  36.627
# 15527  04.11.2018 00:00:00.000 GMT-0700  36.627  36.627  36.627  36.627
# 15528  04.11.2018 01:00:00.000 GMT-0700  36.627  36.627  36.627  36.627
# 15530  04.11.2018 02:00:00.000 GMT-0800  36.627  36.627  36.627  36.627
# 15531  04.11.2018 03:00:00.000 GMT-0800  36.627  36.627  36.627  36.627
#
#        Volume                local_time
# 15526     0.0 2018-11-03 16:00:00+00:00
# 15527     0.0 2018-11-03 17:00:00+00:00
# 15528     0.0 2018-11-03 18:00:00+00:00
# 15530     0.0 2018-11-03 18:00:00+00:00
# 15531     0.0 2018-11-03 19:00:00+00:00

# %%
vix_volatility_hourly_history_df.drop(15530, inplace = True)

# %%
vix_volatility_hourly_history_df[vix_volatility_hourly_history_df.local_time == '2017-11-04 18:00:00+00:00']
# Out:
#                             Local time    Open    High     Low   Close  \
# 6792  05.11.2017 01:00:00.000 GMT-0700  33.647  33.647  33.647  33.647
# 6794  05.11.2017 02:00:00.000 GMT-0800  33.647  33.647  33.647  33.647
#
#       Volume                local_time
# 6792     0.0 2017-11-04 18:00:00+00:00
# 6794     0.0 2017-11-04 18:00:00+00:00

# %%
vix_volatility_hourly_history_df[6790:6796]
# Out:
#                             Local time    Open    High     Low   Close  \
# 6790  04.11.2017 23:00:00.000 GMT-0700  33.647  33.647  33.647  33.647
# 6791  05.11.2017 00:00:00.000 GMT-0700  33.647  33.647  33.647  33.647
# 6792  05.11.2017 01:00:00.000 GMT-0700  33.647  33.647  33.647  33.647
# 6793  05.11.2017 01:00:00.000 GMT-0800  33.647  33.647  33.647  33.647
# 6794  05.11.2017 02:00:00.000 GMT-0800  33.647  33.647  33.647  33.647
# 6795  05.11.2017 03:00:00.000 GMT-0800  33.647  33.647  33.647  33.647
#
#       Volume                local_time
# 6790     0.0 2017-11-04 16:00:00+00:00
# 6791     0.0 2017-11-04 17:00:00+00:00
# 6792     0.0 2017-11-04 18:00:00+00:00
# 6793     0.0 2017-11-04 17:00:00+00:00
# 6794     0.0 2017-11-04 18:00:00+00:00
# 6795     0.0 2017-11-04 19:00:00+00:00

# %%
vix_volatility_hourly_history_df.drop([6793, 6794, ], inplace = True)

# %%
vix_volatility_hourly_history_df[6790:6796]
# Out:
#                             Local time    Open    High     Low   Close  \
# 6790  04.11.2017 23:00:00.000 GMT-0700  33.647  33.647  33.647  33.647
# 6791  05.11.2017 00:00:00.000 GMT-0700  33.647  33.647  33.647  33.647
# 6792  05.11.2017 01:00:00.000 GMT-0700  33.647  33.647  33.647  33.647
# 6795  05.11.2017 03:00:00.000 GMT-0800  33.647  33.647  33.647  33.647
# 6796  05.11.2017 04:00:00.000 GMT-0800  33.647  33.647  33.647  33.647
# 6797  05.11.2017 05:00:00.000 GMT-0800  33.647  33.647  33.647  33.647
#
#       Volume                local_time
# 6790     0.0 2017-11-04 16:00:00+00:00
# 6791     0.0 2017-11-04 17:00:00+00:00
# 6792     0.0 2017-11-04 18:00:00+00:00
# 6795     0.0 2017-11-04 19:00:00+00:00
# 6796     0.0 2017-11-04 20:00:00+00:00
# 6797     0.0 2017-11-04 21:00:00+00:00

# %%
vix_volatility_hourly_history_df['local_time'].value_counts()
# Out:
# 2017-09-18 20:00:00+00:00    1
# 2019-04-27 08:00:00+00:00    1
# 2018-07-23 14:00:00+00:00    1
# 2019-05-11 23:00:00+00:00    1
# 2018-07-11 08:00:00+00:00    1
# 2017-04-23 17:00:00+00:00    1
# 2018-12-18 13:00:00+00:00    1
# 2018-12-26 18:00:00+00:00    1
# 2017-07-28 00:00:00+00:00    1
# 2018-12-08 03:00:00+00:00    1
# 2017-11-09 16:00:00+00:00    1
# 2018-08-07 23:00:00+00:00    1
# 2017-04-05 19:00:00+00:00    1
# 2018-12-22 07:00:00+00:00    1
# 2018-11-07 04:00:00+00:00    1
# 2017-07-10 02:00:00+00:00    1
# 2017-10-02 22:00:00+00:00    1
# 2017-10-11 04:00:00+00:00    1
# 2018-11-01 05:00:00+00:00    1
# 2017-08-14 22:00:00+00:00    1
# 2017-10-08 03:00:00+00:00    1
# 2017-12-09 10:00:00+00:00    1
# 2018-11-11 12:00:00+00:00    1
# 2018-04-16 06:00:00+00:00    1
# 2018-04-08 13:00:00+00:00    1
# 2019-03-01 08:00:00+00:00    1
# 2017-11-23 14:00:00+00:00    1
# 2017-05-29 13:00:00+00:00    1
# 2018-02-16 22:00:00+00:00    1
# 2018-01-12 10:00:00+00:00    1
#                             ..
# 2017-02-12 03:00:00+00:00    1
# 2018-07-19 13:00:00+00:00    1
# 2018-04-11 10:00:00+00:00    1
# 2018-04-07 10:00:00+00:00    1
# 2018-08-12 00:00:00+00:00    1
# 2018-01-09 13:00:00+00:00    1
# 2017-02-03 04:00:00+00:00    1
# 2017-08-30 16:00:00+00:00    1
# 2018-03-14 17:00:00+00:00    1
# 2018-03-19 04:00:00+00:00    1
# 2018-07-02 07:00:00+00:00    1
# 2018-12-31 10:00:00+00:00    1
# 2018-06-09 11:00:00+00:00    1
# 2018-10-30 16:00:00+00:00    1
# 2017-04-06 21:00:00+00:00    1
# 2018-12-24 22:00:00+00:00    1
# 2018-09-19 17:00:00+00:00    1
# 2017-12-20 16:00:00+00:00    1
# 2017-03-28 22:00:00+00:00    1
# 2018-12-14 10:00:00+00:00    1
# 2018-12-16 10:00:00+00:00    1
# 2018-05-02 00:00:00+00:00    1
# 2017-03-19 23:00:00+00:00    1
# 2017-09-30 13:00:00+00:00    1
# 2019-02-19 12:00:00+00:00    1
# 2018-07-09 22:00:00+00:00    1
# 2017-11-16 22:00:00+00:00    1
# 2018-01-04 21:00:00+00:00    1
# 2017-03-11 00:00:00+00:00    1
# 2019-01-15 12:00:00+00:00    1
# Name: local_time, Length: 20731, dtype: int64

# %%
vix_volatility_hourly_history_df.head()
# Out:
#                          Local time   Open   High    Low  Close  Volume  \
# 0  26.01.2017 00:00:00.000 GMT-0800  19.14  19.14  19.14  19.14     0.0
# 1  26.01.2017 01:00:00.000 GMT-0800  19.14  19.14  19.14  19.14     0.0
# 2  26.01.2017 02:00:00.000 GMT-0800  19.14  19.14  19.14  19.14     0.0
# 3  26.01.2017 03:00:00.000 GMT-0800  19.14  19.14  19.14  19.14     0.0
# 4  26.01.2017 04:00:00.000 GMT-0800  19.14  19.14  19.14  19.14     0.0
#
#                  local_time
# 0 2017-01-25 16:00:00+00:00
# 1 2017-01-25 17:00:00+00:00
# 2 2017-01-25 18:00:00+00:00
# 3 2017-01-25 19:00:00+00:00
# 4 2017-01-25 20:00:00+00:00

# %%
vix_volatility_hourly_history_df.to_pickle('./data/vix_volatility_hourly_history_df.pickle')
