# %%
import plaidml.keras
plaidml.keras.install_backend()

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

import statsmodels.api as sm
import statsmodels.tsa.api as smt
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.tsa.stattools as ts
from statsmodels.tsa.stattools import adfuller

from fbprophet import Prophet

import math

# import pyflux as pf

import warnings
warnings.filterwarnings(action='once')

import itertools

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import TimeSeriesSplit

from pandas.plotting import autocorrelation_plot

import re

import sys
import os

from functools import reduce

import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout, Input, LSTM
#from keras.layers import Concatbenate
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.utils.data_utils import get_file
from keras.preprocessing.text import Tokenizer
from keras.utils.vis_utils import model_to_dot, plot_model
from keras.datasets import imdb, reuters
from keras.preprocessing import sequence
from keras.optimizers import SGD, RMSprop
from keras.models import load_model

import datetime as dt

from sklearn.preprocessing import StandardScaler, MinMaxScaler

import pickle

from numpy.random import seed

from tensorflow import set_random_seed

# %%
seed(2019)
set_random_seed(2019)

# %%
df_combined = pd.read_pickle('./processed_data/df_combined.pickle')

df_combined.tail(2)
# Out:
#                        ds        y     vix     gold
# 12666 2019-06-01 22:00:00  8568.81  30.447  3561.58
# 12667 2019-06-01 23:00:00  8560.63  30.447  3569.34

# %%
df_daily = df_combined[df_combined.ds.dt.hour == 0]

# %%
df_daily.reset_index(inplace=True, drop = True)

# %%
df_daily.head(3)
# Out:
#           ds        y     vix     gold
# 0 2017-02-08  1054.03  18.879  2732.00
# 1 2017-02-09  1059.04  18.619  2703.51
# 2 2017-02-10   986.42  18.165  2793.34

# %%
def split_train_test_chronological(df, ratio = 0.9, use_ratio = True, index = 1000):
    
    '''
    Input is a dataframe, and a ratio. Splits dataframe into 2 dataframes chronologically.
    Returns first dataframe up to the index of the length of the input dataframe times the input ratio, 
    and returns second dataframe of remaining elements.
    use_ratio is a flag, wether ratio should be used or indicies instead.
    
    df = input dataframe
    ratio = ratio to be used for splitting
    use_ratio = if True, use ratio, 
    index = index to split input dataframe on
    
    '''
    if use_ratio:
        size = len(df) * ratio
        size_round = round(size)

        df_train = df[0:(size_round)]
        df_test = df[size_round:]
    else:
        df_train = df[0:(index)]
        df_test = df[index:]
    return df_train, df_test

# %%
def make_variables(df, lags, look_back, predict_window):
    
    '''
    In order to use keras LSTM, we need to convert the input into a keras-friendly input.
    
    df = input dataframe
    lags = number of lags
    look_back = number of preceding elements to be considered
    predict_window = size of window for predictions
    
    '''
    
    features = lags + 1
    start = look_back
    stop = len(df) - lags - predict_window

    lstm_in_X = np.zeros(shape=(stop-start, look_back+1, features))
    lstm_in_Y = np.zeros(shape=(stop-start, look_back+1))

    iter_list = [num for num in range(look_back+1)][::-1]
    for i in range(start, stop):
        for index, j in enumerate(iter_list):
            X = df[i - j : i - j + lags + 1, -1]
            lstm_in_X[i - start, index] = np.ravel(X)
            Y = df[i - j + lags + 1, -1]
            lstm_in_Y[i-start, index] = Y
            
    return lstm_in_X, lstm_in_Y, features

# %%
def train_lstm(train_X, train_Y, lags, look_back, predict_window, lstm_nodes,
               dense_layers, dropout = 0.1, loss_type = 'hinge', optimizer_type = 'adam',
               number_epochs = 300, batch_size = 24, ):
    
    
    model = Sequential()
    model.add(LSTM(lstm_nodes, input_shape=(look_back+1, features)))
    model.add(Dropout(dropout))
    for nodes in dense_layers:
        model.add(Dense(nodes))
        model.add(Dropout(dropout))
    model.add(Dense(look_back + 1))
    model.compile(loss=loss_type, optimizer= optimizer_type)
    model.fit(train_X, train_Y, epochs=number_epochs, batch_size = batch_size, verbose = 1)
    
    pred_Y_train = model.predict(train_X)
    predictions = pred_Y_train[:,-1]
    actuals = train_Y[:,-1]
    
    print(model.summary())
    
    return model, dataset, train_X, train_Y, predictions, actuals

# %%
def make_rolling_window(model, train_x, train_y, test_x, test_y, batch_size = 218, epochs = 2):
    predictions_test = []
    actuals_test = []
    yhats = []
    ys = []
    
    dimension = train_x.shape[2]
    
    for i in range(0, len(test_y) - 1):
        model.fit(train_x, train_y, 
                    epochs= epochs, 
                    batch_size = batch_size, 
                    validation_data=(test_x[i].reshape(1,1,dimension), (test_y[i].reshape(1 ,))),
                    verbose=2,
#                     callbacks=[earlystopper],
                    shuffle=False)
        pred_Y_test = model.predict(test_x[i].reshape(1,1,dimension))
        train_x = np.concatenate((train_x, (test_x[i].reshape(1 , 1 , dimension))))

        train_y = np.concatenate((train_y, (test_y[i].reshape(1 ,))))
        predict_test = pred_Y_test[-1,-1]
        actual_test = train_y[-1]
        predictions_test.append(predict_test)
        actuals_test.append(actual_test)
        yhats.append(pred_Y_test)
        ys.append(test_y[i])
        
    return predictions_test, actuals_test, yhats, ys

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    '''
    
    
    '''
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# load dataset
values = df_daily.drop('ds', axis = 1).values
# values = df_combined.drop('ds', axis = 1).values
# integer encode direction
# ensure all data is float
values = values.astype('float32')
# normalize features
# scaler = MinMaxScaler()
scaler = StandardScaler()
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 7, 1)
reframed.head()
# reframed_2 = series_to_supervised(values, 7, 1)
# reframed_2.head()

# drop columns we don't want to predict
y = reframed.iloc[:,-12].values
X = reframed.drop('var1(t)', axis =1).values
# split into train and test sets

n_train_days = 500
n_test_days = 10
train_X = X[:n_train_days,:]
train_y = y[:n_train_days]

val_X= X[n_train_days:-n_test_days,]
val_y= y[n_train_days:-n_test_days]


test_X = X[-n_test_days:,:]
test_y = y[-n_test_days:]



# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

train_and_val_X = np.concatenate((train_X, val_X), axis = 0)

train_and_val_y = np.concatenate((train_y, val_y), axis = 0)

print(train_X.shape, train_y.shape,val_X.shape, val_y.shape ,test_X.shape, test_y.shape)
# Out:
# (500, 1, 23) (500,) (11, 1, 23) (11,) (10, 1, 23) (10,)

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(np.array(df_daily.y[:n_train_days]).reshape(-1,1))

# %%
LSTM_model_daily_1 = Sequential()
LSTM_model_daily_1.add(LSTM(64, activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), dropout=0.20,recurrent_dropout=0.20))
# LSTM_model_daily_1.add(LSTM(128))
LSTM_model_daily_1.add(Dense(32))
LSTM_model_daily_1.add(Dense(32))
# LSTM_model_daily_1.add(LSTM(16, activation='relu'))
LSTM_model_daily_1.add(Dense(1))
LSTM_model_daily_1.compile(optimizer='adam', loss='mse')

# %%
history_daily_1 = LSTM_model_daily_1.fit(train_X, train_y, 
                    epochs= 200, 
                    batch_size = 32, 
                    validation_data=(val_X, val_y),
                    verbose=2,
#                     callbacks=[earlystopper],
                    shuffle=False)
# Out:
# Train on 500 samples, validate on 11 samples
# Epoch 1/200
#  - 0s - loss: 0.7781 - val_loss: 0.3023
# Epoch 2/200
#  - 0s - loss: 0.2174 - val_loss: 0.0447
# Epoch 3/200
#  - 0s - loss: 0.1019 - val_loss: 0.0073
# Epoch 4/200
#  - 0s - loss: 0.0669 - val_loss: 0.0072
# Epoch 5/200
#  - 0s - loss: 0.0505 - val_loss: 0.0056
# Epoch 6/200
#  - 0s - loss: 0.0442 - val_loss: 0.0033
# Epoch 7/200
#  - 0s - loss: 0.0496 - val_loss: 0.0084
# Epoch 8/200
#  - 0s - loss: 0.0454 - val_loss: 0.0020
# Epoch 9/200
#  - 0s - loss: 0.0444 - val_loss: 0.0224
# Epoch 10/200
#  - 0s - loss: 0.0436 - val_loss: 0.0022
# Epoch 11/200
#  - 0s - loss: 0.0473 - val_loss: 0.0152
# Epoch 12/200
#  - 0s - loss: 0.0595 - val_loss: 0.0104
# Epoch 13/200
#  - 0s - loss: 0.0719 - val_loss: 0.0425
# Epoch 14/200
#  - 0s - loss: 0.0858 - val_loss: 0.0479
# Epoch 15/200
#  - 0s - loss: 0.1341 - val_loss: 0.0389
# Epoch 16/200
#  - 0s - loss: 0.0535 - val_loss: 0.0407
# Epoch 17/200
#  - 0s - loss: 0.0719 - val_loss: 0.0742
# Epoch 18/200
#  - 0s - loss: 0.0581 - val_loss: 0.0184
# Epoch 19/200
#  - 0s - loss: 0.0720 - val_loss: 0.0298
# Epoch 20/200
#  - 0s - loss: 0.0619 - val_loss: 0.0116
# Epoch 21/200
#  - 0s - loss: 0.0691 - val_loss: 0.0364
# Epoch 22/200
#  - 0s - loss: 0.0396 - val_loss: 0.0200
# Epoch 23/200
#  - 0s - loss: 0.0577 - val_loss: 0.0270
# Epoch 24/200
#  - 0s - loss: 0.0463 - val_loss: 0.0198
# Epoch 25/200
#  - 0s - loss: 0.0590 - val_loss: 0.0346
# Epoch 26/200
#  - 0s - loss: 0.0629 - val_loss: 0.0216
# Epoch 27/200
#  - 0s - loss: 0.0883 - val_loss: 0.0134
# Epoch 28/200
#  - 0s - loss: 0.0475 - val_loss: 0.0014
# Epoch 29/200
#  - 0s - loss: 0.0514 - val_loss: 0.0151
# Epoch 30/200
#  - 0s - loss: 0.0458 - val_loss: 0.0043
# Epoch 31/200
#  - 0s - loss: 0.0593 - val_loss: 0.0151
# Epoch 32/200
#  - 0s - loss: 0.0424 - val_loss: 0.0078
# Epoch 33/200
#  - 0s - loss: 0.0754 - val_loss: 0.0342
# Epoch 34/200
#  - 0s - loss: 0.0575 - val_loss: 0.0662
# Epoch 35/200
#  - 0s - loss: 0.0837 - val_loss: 0.0366
# Epoch 36/200
#  - 0s - loss: 0.0648 - val_loss: 0.0382
# Epoch 37/200
#  - 0s - loss: 0.0821 - val_loss: 0.0172
# Epoch 38/200
#  - 0s - loss: 0.0486 - val_loss: 0.0195
# Epoch 39/200
#  - 0s - loss: 0.0612 - val_loss: 0.0164
# Epoch 40/200
#  - 0s - loss: 0.0538 - val_loss: 0.0159
# Epoch 41/200
#  - 0s - loss: 0.0810 - val_loss: 0.0137
# Epoch 42/200
#  - 0s - loss: 0.0482 - val_loss: 0.0200
# Epoch 43/200
#  - 0s - loss: 0.0549 - val_loss: 0.0180
# Epoch 44/200
#  - 0s - loss: 0.0446 - val_loss: 0.0092
# Epoch 45/200
#  - 0s - loss: 0.0454 - val_loss: 0.0286
# Epoch 46/200
#  - 0s - loss: 0.0344 - val_loss: 0.0064
# Epoch 47/200
#  - 0s - loss: 0.0380 - val_loss: 0.0067
# Epoch 48/200
#  - 0s - loss: 0.0404 - val_loss: 0.0166
# Epoch 49/200
#  - 0s - loss: 0.0421 - val_loss: 0.0176
# Epoch 50/200
#  - 0s - loss: 0.0414 - val_loss: 0.0205
# Epoch 51/200
#  - 0s - loss: 0.0559 - val_loss: 0.0240
# Epoch 52/200
#  - 0s - loss: 0.0531 - val_loss: 0.0187
# Epoch 53/200
#  - 0s - loss: 0.0882 - val_loss: 0.0103
# Epoch 54/200
#  - 0s - loss: 0.0618 - val_loss: 0.0394
# Epoch 55/200
#  - 0s - loss: 0.0762 - val_loss: 0.0290
# Epoch 56/200
#  - 0s - loss: 0.0502 - val_loss: 0.0328
# Epoch 57/200
#  - 0s - loss: 0.0539 - val_loss: 0.0206
# Epoch 58/200
#  - 0s - loss: 0.0390 - val_loss: 0.0132
# Epoch 59/200
#  - 0s - loss: 0.0454 - val_loss: 0.0127
# Epoch 60/200
#  - 0s - loss: 0.0400 - val_loss: 0.0038
# Epoch 61/200
#  - 0s - loss: 0.0409 - val_loss: 0.0120
# Epoch 62/200
#  - 0s - loss: 0.0377 - val_loss: 0.0136
# Epoch 63/200
#  - 0s - loss: 0.0386 - val_loss: 0.0248
# Epoch 64/200
#  - 0s - loss: 0.0431 - val_loss: 0.0226
# Epoch 65/200
#  - 0s - loss: 0.0613 - val_loss: 0.0336
# Epoch 66/200
#  - 0s - loss: 0.0586 - val_loss: 0.0368
# Epoch 67/200
#  - 0s - loss: 0.1005 - val_loss: 0.0256
# Epoch 68/200
#  - 0s - loss: 0.0557 - val_loss: 0.0236
# Epoch 69/200
#  - 0s - loss: 0.0969 - val_loss: 0.0265
# Epoch 70/200
#  - 0s - loss: 0.0466 - val_loss: 0.0439
# Epoch 71/200
#  - 0s - loss: 0.0446 - val_loss: 0.0215
# Epoch 72/200
#  - 0s - loss: 0.0360 - val_loss: 0.0179
# Epoch 73/200
#  - 0s - loss: 0.0375 - val_loss: 0.0132
# Epoch 74/200
#  - 0s - loss: 0.0274 - val_loss: 0.0066
# Epoch 75/200
#  - 0s - loss: 0.0312 - val_loss: 0.0057
# Epoch 76/200
#  - 0s - loss: 0.0306 - val_loss: 0.0014
# Epoch 77/200
#  - 0s - loss: 0.0320 - val_loss: 0.0011
# Epoch 78/200
#  - 0s - loss: 0.0283 - val_loss: 0.0021
# Epoch 79/200
#  - 0s - loss: 0.0274 - val_loss: 0.0012
# Epoch 80/200
#  - 0s - loss: 0.0368 - val_loss: 0.0032
# Epoch 81/200
#  - 0s - loss: 0.0392 - val_loss: 0.0039
# Epoch 82/200
#  - 0s - loss: 0.0611 - val_loss: 0.0058
# Epoch 83/200
#  - 0s - loss: 0.0516 - val_loss: 0.0196
# Epoch 84/200
#  - 0s - loss: 0.0858 - val_loss: 0.0280
# Epoch 85/200
#  - 0s - loss: 0.0601 - val_loss: 0.0537
# Epoch 86/200
#  - 0s - loss: 0.0910 - val_loss: 0.0446
# Epoch 87/200
#  - 0s - loss: 0.0576 - val_loss: 0.0474
# Epoch 88/200
#  - 0s - loss: 0.0889 - val_loss: 0.0423
# Epoch 89/200
#  - 0s - loss: 0.0462 - val_loss: 0.0309
# Epoch 90/200
#  - 0s - loss: 0.0538 - val_loss: 0.0163
# Epoch 91/200
#  - 0s - loss: 0.0493 - val_loss: 0.0128
# Epoch 92/200
#  - 0s - loss: 0.0631 - val_loss: 0.0292
# Epoch 93/200
#  - 0s - loss: 0.0490 - val_loss: 0.0259
# Epoch 94/200
#  - 0s - loss: 0.0606 - val_loss: 0.0143
# Epoch 95/200
#  - 0s - loss: 0.0384 - val_loss: 0.0157
# Epoch 96/200
#  - 0s - loss: 0.0548 - val_loss: 0.0141
# Epoch 97/200
#  - 0s - loss: 0.0392 - val_loss: 0.0182
# Epoch 98/200
#  - 0s - loss: 0.0413 - val_loss: 0.0138
# Epoch 99/200
#  - 0s - loss: 0.0327 - val_loss: 0.0025
# Epoch 100/200
#  - 0s - loss: 0.0366 - val_loss: 0.0016
# Epoch 101/200
#  - 0s - loss: 0.0310 - val_loss: 0.0016
# Epoch 102/200
#  - 0s - loss: 0.0291 - val_loss: 0.0023
# Epoch 103/200
#  - 0s - loss: 0.0246 - val_loss: 0.0058
# Epoch 104/200
#  - 0s - loss: 0.0301 - val_loss: 0.0026
# Epoch 105/200
#  - 0s - loss: 0.0287 - val_loss: 0.0116
# Epoch 106/200
#  - 0s - loss: 0.0301 - val_loss: 0.0143
# Epoch 107/200
#  - 0s - loss: 0.0464 - val_loss: 0.0355
# Epoch 108/200
#  - 0s - loss: 0.0738 - val_loss: 0.0310
# Epoch 109/200
#  - 0s - loss: 0.0427 - val_loss: 0.0352
# Epoch 110/200
#  - 0s - loss: 0.0700 - val_loss: 0.0126
# Epoch 111/200
#  - 0s - loss: 0.0357 - val_loss: 0.0186
# Epoch 112/200
#  - 0s - loss: 0.0478 - val_loss: 0.0153
# Epoch 113/200
#  - 0s - loss: 0.0365 - val_loss: 0.0202
# Epoch 114/200
#  - 0s - loss: 0.0462 - val_loss: 0.0105
# Epoch 115/200
#  - 0s - loss: 0.0351 - val_loss: 0.0100
# Epoch 116/200
#  - 0s - loss: 0.0530 - val_loss: 0.0085
# Epoch 117/200
#  - 0s - loss: 0.0426 - val_loss: 0.0138
# Epoch 118/200
#  - 0s - loss: 0.0628 - val_loss: 0.0175
# Epoch 119/200
#  - 0s - loss: 0.0327 - val_loss: 0.0069
# Epoch 120/200
#  - 0s - loss: 0.0241 - val_loss: 0.0053
# Epoch 121/200
#  - 0s - loss: 0.0238 - val_loss: 0.0105
# Epoch 122/200
#  - 0s - loss: 0.0318 - val_loss: 0.0111
# Epoch 123/200
#  - 0s - loss: 0.0237 - val_loss: 0.0103
# Epoch 124/200
#  - 0s - loss: 0.0252 - val_loss: 0.0052
# Epoch 125/200
#  - 0s - loss: 0.0334 - val_loss: 0.0232
# Epoch 126/200
#  - 0s - loss: 0.0545 - val_loss: 0.0098
# Epoch 127/200
#  - 0s - loss: 0.0439 - val_loss: 0.0415
# Epoch 128/200
#  - 0s - loss: 0.0491 - val_loss: 0.0121
# Epoch 129/200
#  - 0s - loss: 0.0431 - val_loss: 0.0209
# Epoch 130/200
#  - 0s - loss: 0.0476 - val_loss: 0.0186
# Epoch 131/200
#  - 0s - loss: 0.0403 - val_loss: 0.0480
# Epoch 132/200
#  - 0s - loss: 0.0659 - val_loss: 0.0102
# Epoch 133/200
#  - 0s - loss: 0.0532 - val_loss: 0.0526
# Epoch 134/200
#  - 0s - loss: 0.0786 - val_loss: 0.0153
# Epoch 135/200
#  - 0s - loss: 0.0390 - val_loss: 0.0138
# Epoch 136/200
#  - 0s - loss: 0.0492 - val_loss: 0.0077
# Epoch 137/200
#  - 0s - loss: 0.0333 - val_loss: 0.0052
# Epoch 138/200
#  - 0s - loss: 0.0435 - val_loss: 0.0113
# Epoch 139/200
#  - 0s - loss: 0.0265 - val_loss: 0.0210
# Epoch 140/200
#  - 0s - loss: 0.0288 - val_loss: 0.0030
# Epoch 141/200
#  - 0s - loss: 0.0305 - val_loss: 0.0166
# Epoch 142/200
#  - 0s - loss: 0.0336 - val_loss: 0.0194
# Epoch 143/200
#  - 0s - loss: 0.0216 - val_loss: 0.0106
# Epoch 144/200
#  - 0s - loss: 0.0231 - val_loss: 0.0031
# Epoch 145/200
#  - 0s - loss: 0.0277 - val_loss: 0.0196
# Epoch 146/200
#  - 0s - loss: 0.0437 - val_loss: 0.0038
# Epoch 147/200
#  - 0s - loss: 0.0364 - val_loss: 0.0206
# Epoch 148/200
#  - 0s - loss: 0.0609 - val_loss: 0.0088
# Epoch 149/200
#  - 0s - loss: 0.0521 - val_loss: 0.0186
# Epoch 150/200
#  - 0s - loss: 0.0616 - val_loss: 0.0144
# Epoch 151/200
#  - 0s - loss: 0.0357 - val_loss: 0.0339
# Epoch 152/200
#  - 0s - loss: 0.0441 - val_loss: 0.0075
# Epoch 153/200
#  - 0s - loss: 0.0377 - val_loss: 0.0192
# Epoch 154/200
#  - 0s - loss: 0.0406 - val_loss: 0.0075
# Epoch 155/200
#  - 0s - loss: 0.0297 - val_loss: 0.0200
# Epoch 156/200
#  - 0s - loss: 0.0331 - val_loss: 0.0054
# Epoch 157/200
#  - 0s - loss: 0.0308 - val_loss: 0.0183
# Epoch 158/200
#  - 0s - loss: 0.0323 - val_loss: 0.0016
# Epoch 159/200
#  - 0s - loss: 0.0344 - val_loss: 0.0183
# Epoch 160/200
#  - 0s - loss: 0.0510 - val_loss: 0.0017
# Epoch 161/200
#  - 0s - loss: 0.0388 - val_loss: 0.0116
# Epoch 162/200
#  - 0s - loss: 0.0419 - val_loss: 0.0051
# Epoch 163/200
#  - 0s - loss: 0.0300 - val_loss: 0.0295
# Epoch 164/200
#  - 0s - loss: 0.0346 - val_loss: 0.0097
# Epoch 165/200
#  - 0s - loss: 0.0331 - val_loss: 0.0277
# Epoch 166/200
#  - 0s - loss: 0.0473 - val_loss: 0.0112
# Epoch 167/200
#  - 0s - loss: 0.0400 - val_loss: 0.0475
# Epoch 168/200
#  - 0s - loss: 0.0643 - val_loss: 0.0068
# Epoch 169/200
#  - 0s - loss: 0.0364 - val_loss: 0.0168
# Epoch 170/200
#  - 0s - loss: 0.0342 - val_loss: 0.0059
# Epoch 171/200
#  - 0s - loss: 0.0306 - val_loss: 0.0176
# Epoch 172/200
#  - 0s - loss: 0.0312 - val_loss: 0.0077
# Epoch 173/200
#  - 0s - loss: 0.0265 - val_loss: 0.0271
# Epoch 174/200
#  - 0s - loss: 0.0310 - val_loss: 0.0101
# Epoch 175/200
#  - 0s - loss: 0.0278 - val_loss: 0.0420
# Epoch 176/200
#  - 0s - loss: 0.0344 - val_loss: 0.0057
# Epoch 177/200
#  - 0s - loss: 0.0342 - val_loss: 0.0275
# Epoch 178/200
#  - 0s - loss: 0.0440 - val_loss: 0.0091
# Epoch 179/200
#  - 0s - loss: 0.0407 - val_loss: 0.0415
# Epoch 180/200
#  - 0s - loss: 0.0497 - val_loss: 0.0076
# Epoch 181/200
#  - 0s - loss: 0.0429 - val_loss: 0.0212
# Epoch 182/200
#  - 0s - loss: 0.0627 - val_loss: 0.0042
# Epoch 183/200
#  - 0s - loss: 0.0278 - val_loss: 0.0085
# Epoch 184/200
#  - 0s - loss: 0.0286 - val_loss: 0.0021
# Epoch 185/200
#  - 0s - loss: 0.0244 - val_loss: 0.0086
# Epoch 186/200
#  - 0s - loss: 0.0246 - val_loss: 0.0038
# Epoch 187/200
#  - 0s - loss: 0.0166 - val_loss: 0.0052
# Epoch 188/200
#  - 0s - loss: 0.0242 - val_loss: 0.0032
# Epoch 189/200
#  - 0s - loss: 0.0178 - val_loss: 0.0167
# Epoch 190/200
#  - 0s - loss: 0.0191 - val_loss: 0.0042
# Epoch 191/200
#  - 0s - loss: 0.0179 - val_loss: 0.0197
# Epoch 192/200
#  - 0s - loss: 0.0247 - val_loss: 0.0026
# Epoch 193/200
#  - 0s - loss: 0.0313 - val_loss: 0.0465
# Epoch 194/200
#  - 0s - loss: 0.0443 - val_loss: 0.0092
# Epoch 195/200
#  - 0s - loss: 0.0424 - val_loss: 0.0544
# Epoch 196/200
#  - 0s - loss: 0.0602 - val_loss: 0.0104
# Epoch 197/200
#  - 0s - loss: 0.0442 - val_loss: 0.0429
# Epoch 198/200
#  - 0s - loss: 0.0694 - val_loss: 0.0122
# Epoch 199/200
#  - 0s - loss: 0.0487 - val_loss: 0.0368
# Epoch 200/200
#  - 0s - loss: 0.0678 - val_loss: 0.0058

# %%
res_1 = make_rolling_window(LSTM_model_daily_1, train_X, train_y, val_X, val_y, batch_size = 32, epochs = 2)
# Out:
# Train on 500 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0469 - val_loss: 0.0300
# Epoch 2/2
#  - 0s - loss: 0.0592 - val_loss: 0.0096
# Train on 501 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0406 - val_loss: 0.0184
# Epoch 2/2
#  - 0s - loss: 0.0731 - val_loss: 0.0099
# Train on 502 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0385 - val_loss: 0.0406
# Epoch 2/2
#  - 0s - loss: 0.0513 - val_loss: 1.6457e-04
# Train on 503 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0364 - val_loss: 0.0528
# Epoch 2/2
#  - 0s - loss: 0.0517 - val_loss: 7.1228e-04
# Train on 504 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0324 - val_loss: 0.0392
# Epoch 2/2
#  - 0s - loss: 0.0463 - val_loss: 2.9368e-04
# Train on 505 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0294 - val_loss: 0.0449
# Epoch 2/2
#  - 0s - loss: 0.0287 - val_loss: 0.0051
# Train on 506 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0272 - val_loss: 0.0120
# Epoch 2/2
#  - 0s - loss: 0.0285 - val_loss: 0.0015
# Train on 507 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0291 - val_loss: 0.0113
# Epoch 2/2
#  - 0s - loss: 0.0387 - val_loss: 0.0044
# Train on 508 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0352 - val_loss: 0.0216
# Epoch 2/2
#  - 0s - loss: 0.0515 - val_loss: 0.0227
# Train on 509 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0287 - val_loss: 0.0122
# Epoch 2/2
#  - 0s - loss: 0.0269 - val_loss: 0.0023

# %%
predicts_1 = scaler.inverse_transform(np.array(res_1[0]))
actuals_1 = scaler.inverse_transform(np.array(res_1[1]))
rmse = math.sqrt(mean_squared_error(predicts_1, actuals_1))
print('Validation RMSE: %.3f' % rmse)
# Out:
# Validation RMSE: 247.169

# %%
res_test = make_rolling_window(LSTM_model_daily_1, train_and_val_X, train_and_val_y, test_X, test_y, batch_size = 32, epochs = 2)
# Out:
# Train on 511 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0270 - val_loss: 0.0116
# Epoch 2/2
#  - 0s - loss: 0.0311 - val_loss: 2.1841e-05
# Train on 512 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0274 - val_loss: 0.0013
# Epoch 2/2
#  - 0s - loss: 0.0340 - val_loss: 0.0100
# Train on 513 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0340 - val_loss: 0.0159
# Epoch 2/2
#  - 0s - loss: 0.0586 - val_loss: 0.0039
# Train on 514 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0492 - val_loss: 0.1260
# Epoch 2/2
#  - 0s - loss: 0.0710 - val_loss: 0.0076
# Train on 515 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0544 - val_loss: 0.1655
# Epoch 2/2
#  - 0s - loss: 0.0752 - val_loss: 0.0095
# Train on 516 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0572 - val_loss: 0.0789
# Epoch 2/2
#  - 0s - loss: 0.1047 - val_loss: 0.0065
# Train on 517 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0483 - val_loss: 0.0793
# Epoch 2/2
#  - 0s - loss: 0.0767 - val_loss: 0.0161
# Train on 518 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0539 - val_loss: 0.0737
# Epoch 2/2
#  - 0s - loss: 0.0629 - val_loss: 0.0052
# Train on 519 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0262 - val_loss: 0.0331
# Epoch 2/2
#  - 0s - loss: 0.0228 - val_loss: 0.0029

# %%
predicts_1 = scaler.inverse_transform(np.array(res_test[0]))
actuals_1 = scaler.inverse_transform(np.array(res_test[1]))
rmse = math.sqrt(mean_squared_error(predicts_1, actuals_1))
print('TEST RMSE: %.3f' % rmse)
# Out:
# TEST RMSE: 271.686

# %%
LSTM_model_daily_2 = Sequential()
LSTM_model_daily_2.add(LSTM(128, activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), dropout=0.20,recurrent_dropout=0.20))
# LSTM_model_daily_2.add(LSTM(128))
LSTM_model_daily_2.add(Dense(64))
LSTM_model_daily_2.add(Dense(64))
# LSTM_model_daily_2.add(LSTM(16, activation='relu'))
LSTM_model_daily_2.add(Dense(1))
LSTM_model_daily_2.compile(optimizer='adam', loss='mse')

# %%
history_daily_2 = LSTM_model_daily_2.fit(train_X, train_y, 
                    epochs= 200, 
                    batch_size = 32, 
                    validation_data=(val_X, val_y),
                    verbose=2,
#                     callbacks=[earlystopper],
                    shuffle=False)
# Out:
# Train on 500 samples, validate on 11 samples
# Epoch 1/200
#  - 7s - loss: 0.8799 - val_loss: 0.2917
# Epoch 2/200
#  - 0s - loss: 0.0909 - val_loss: 0.0472
# Epoch 3/200
#  - 0s - loss: 0.2167 - val_loss: 0.1519
# Epoch 4/200
#  - 0s - loss: 0.2226 - val_loss: 0.0128
# Epoch 5/200
#  - 0s - loss: 0.0560 - val_loss: 0.0202
# Epoch 6/200
#  - 0s - loss: 0.0629 - val_loss: 0.0392
# Epoch 7/200
#  - 0s - loss: 0.0662 - val_loss: 0.0421
# Epoch 8/200
#  - 0s - loss: 0.0488 - val_loss: 0.0244
# Epoch 9/200
#  - 0s - loss: 0.0566 - val_loss: 0.0456
# Epoch 10/200
#  - 0s - loss: 0.0551 - val_loss: 0.0445
# Epoch 11/200
#  - 0s - loss: 0.0652 - val_loss: 0.0853
# Epoch 12/200
#  - 0s - loss: 0.0553 - val_loss: 0.1338
# Epoch 13/200
#  - 0s - loss: 0.0743 - val_loss: 0.0484
# Epoch 14/200
#  - 0s - loss: 0.0665 - val_loss: 0.0919
# Epoch 15/200
#  - 0s - loss: 0.1194 - val_loss: 0.0563
# Epoch 16/200
#  - 0s - loss: 0.1092 - val_loss: 0.1037
# Epoch 17/200
#  - 0s - loss: 0.1998 - val_loss: 0.0119
# Epoch 18/200
#  - 0s - loss: 0.0497 - val_loss: 0.0173
# Epoch 19/200
#  - 0s - loss: 0.0500 - val_loss: 0.0292
# Epoch 20/200
#  - 0s - loss: 0.0493 - val_loss: 0.0295
# Epoch 21/200
#  - 0s - loss: 0.0495 - val_loss: 0.0203
# Epoch 22/200
#  - 0s - loss: 0.0594 - val_loss: 0.0382
# Epoch 23/200
#  - 0s - loss: 0.0640 - val_loss: 0.0172
# Epoch 24/200
#  - 0s - loss: 0.0541 - val_loss: 0.0111
# Epoch 25/200
#  - 0s - loss: 0.0614 - val_loss: 0.0051
# Epoch 26/200
#  - 0s - loss: 0.0793 - val_loss: 0.0051
# Epoch 27/200
#  - 0s - loss: 0.0480 - val_loss: 0.0020
# Epoch 28/200
#  - 0s - loss: 0.0745 - val_loss: 0.0035
# Epoch 29/200
#  - 0s - loss: 0.0594 - val_loss: 0.0095
# Epoch 30/200
#  - 0s - loss: 0.0873 - val_loss: 0.0345
# Epoch 31/200
#  - 0s - loss: 0.0723 - val_loss: 0.1321
# Epoch 32/200
#  - 0s - loss: 0.1161 - val_loss: 0.1078
# Epoch 33/200
#  - 0s - loss: 0.0863 - val_loss: 0.2498
# Epoch 34/200
#  - 0s - loss: 0.1720 - val_loss: 0.0222
# Epoch 35/200
#  - 0s - loss: 0.0531 - val_loss: 0.0146
# Epoch 36/200
#  - 0s - loss: 0.0682 - val_loss: 0.0043
# Epoch 37/200
#  - 0s - loss: 0.0537 - val_loss: 0.0055
# Epoch 38/200
#  - 0s - loss: 0.0941 - val_loss: 0.0239
# Epoch 39/200
#  - 0s - loss: 0.0503 - val_loss: 0.0493
# Epoch 40/200
#  - 0s - loss: 0.0654 - val_loss: 0.0305
# Epoch 41/200
#  - 0s - loss: 0.0416 - val_loss: 0.0630
# Epoch 42/200
#  - 0s - loss: 0.0560 - val_loss: 0.0312
# Epoch 43/200
#  - 0s - loss: 0.0685 - val_loss: 0.0939
# Epoch 44/200
#  - 0s - loss: 0.1165 - val_loss: 0.0569
# Epoch 45/200
#  - 0s - loss: 0.0821 - val_loss: 0.0635
# Epoch 46/200
#  - 0s - loss: 0.1477 - val_loss: 0.0560
# Epoch 47/200
#  - 0s - loss: 0.0476 - val_loss: 0.0746
# Epoch 48/200
#  - 0s - loss: 0.0589 - val_loss: 0.0205
# Epoch 49/200
#  - 0s - loss: 0.0508 - val_loss: 0.0320
# Epoch 50/200
#  - 0s - loss: 0.0527 - val_loss: 0.0308
# Epoch 51/200
#  - 0s - loss: 0.0410 - val_loss: 0.0477
# Epoch 52/200
#  - 0s - loss: 0.0597 - val_loss: 0.0223
# Epoch 53/200
#  - 0s - loss: 0.0454 - val_loss: 0.0277
# Epoch 54/200
#  - 0s - loss: 0.0635 - val_loss: 0.0332
# Epoch 55/200
#  - 0s - loss: 0.0505 - val_loss: 0.0658
# Epoch 56/200
#  - 0s - loss: 0.0721 - val_loss: 0.0265
# Epoch 57/200
#  - 0s - loss: 0.0576 - val_loss: 0.0752
# Epoch 58/200
#  - 0s - loss: 0.0982 - val_loss: 0.0126
# Epoch 59/200
#  - 0s - loss: 0.0531 - val_loss: 0.0548
# Epoch 60/200
#  - 0s - loss: 0.0764 - val_loss: 0.0281
# Epoch 61/200
#  - 0s - loss: 0.0518 - val_loss: 0.0617
# Epoch 62/200
#  - 0s - loss: 0.0741 - val_loss: 0.0252
# Epoch 63/200
#  - 0s - loss: 0.0610 - val_loss: 0.0618
# Epoch 64/200
#  - 0s - loss: 0.0871 - val_loss: 0.0355
# Epoch 65/200
#  - 0s - loss: 0.0531 - val_loss: 0.0261
# Epoch 66/200
#  - 0s - loss: 0.0756 - val_loss: 0.0151
# Epoch 67/200
#  - 0s - loss: 0.0412 - val_loss: 0.0059
# Epoch 68/200
#  - 0s - loss: 0.0503 - val_loss: 0.0086
# Epoch 69/200
#  - 0s - loss: 0.0361 - val_loss: 0.0128
# Epoch 70/200
#  - 0s - loss: 0.0451 - val_loss: 0.0232
# Epoch 71/200
#  - 0s - loss: 0.0436 - val_loss: 0.0323
# Epoch 72/200
#  - 0s - loss: 0.0598 - val_loss: 0.0359
# Epoch 73/200
#  - 0s - loss: 0.0507 - val_loss: 0.0459
# Epoch 74/200
#  - 0s - loss: 0.0622 - val_loss: 0.0216
# Epoch 75/200
#  - 0s - loss: 0.0427 - val_loss: 0.0238
# Epoch 76/200
#  - 0s - loss: 0.0518 - val_loss: 0.0382
# Epoch 77/200
#  - 0s - loss: 0.0368 - val_loss: 0.0209
# Epoch 78/200
#  - 0s - loss: 0.0457 - val_loss: 0.0319
# Epoch 79/200
#  - 0s - loss: 0.0515 - val_loss: 0.0532
# Epoch 80/200
#  - 0s - loss: 0.1041 - val_loss: 0.0526
# Epoch 81/200
#  - 0s - loss: 0.0607 - val_loss: 0.0357
# Epoch 82/200
#  - 0s - loss: 0.0847 - val_loss: 0.0247
# Epoch 83/200
#  - 0s - loss: 0.0548 - val_loss: 0.0404
# Epoch 84/200
#  - 0s - loss: 0.0694 - val_loss: 0.0348
# Epoch 85/200
#  - 0s - loss: 0.0529 - val_loss: 0.0612
# Epoch 86/200
#  - 0s - loss: 0.0757 - val_loss: 0.0254
# Epoch 87/200
#  - 0s - loss: 0.0599 - val_loss: 0.0273
# Epoch 88/200
#  - 0s - loss: 0.0780 - val_loss: 0.0360
# Epoch 89/200
#  - 0s - loss: 0.0431 - val_loss: 0.0441
# Epoch 90/200
#  - 0s - loss: 0.0406 - val_loss: 0.0234
# Epoch 91/200
#  - 0s - loss: 0.0320 - val_loss: 0.0042
# Epoch 92/200
#  - 0s - loss: 0.0336 - val_loss: 0.0112
# Epoch 93/200
#  - 0s - loss: 0.0332 - val_loss: 0.0055
# Epoch 94/200
#  - 0s - loss: 0.0426 - val_loss: 0.0091
# Epoch 95/200
#  - 0s - loss: 0.0383 - val_loss: 0.0410
# Epoch 96/200
#  - 0s - loss: 0.0713 - val_loss: 0.0324
# Epoch 97/200
#  - 0s - loss: 0.0595 - val_loss: 0.0645
# Epoch 98/200
#  - 0s - loss: 0.1014 - val_loss: 0.0299
# Epoch 99/200
#  - 0s - loss: 0.0579 - val_loss: 0.0497
# Epoch 100/200
#  - 0s - loss: 0.0813 - val_loss: 0.0261
# Epoch 101/200
#  - 0s - loss: 0.0510 - val_loss: 0.0288
# Epoch 102/200
#  - 0s - loss: 0.0801 - val_loss: 0.0405
# Epoch 103/200
#  - 0s - loss: 0.0509 - val_loss: 0.0273
# Epoch 104/200
#  - 0s - loss: 0.0768 - val_loss: 0.0290
# Epoch 105/200
#  - 0s - loss: 0.0556 - val_loss: 0.0304
# Epoch 106/200
#  - 0s - loss: 0.0721 - val_loss: 0.0259
# Epoch 107/200
#  - 0s - loss: 0.0453 - val_loss: 0.0384
# Epoch 108/200
#  - 0s - loss: 0.0687 - val_loss: 0.0162
# Epoch 109/200
#  - 0s - loss: 0.0491 - val_loss: 0.0191
# Epoch 110/200
#  - 0s - loss: 0.0598 - val_loss: 0.0274
# Epoch 111/200
#  - 0s - loss: 0.0363 - val_loss: 0.0236
# Epoch 112/200
#  - 0s - loss: 0.0518 - val_loss: 0.0174
# Epoch 113/200
#  - 0s - loss: 0.0315 - val_loss: 0.0259
# Epoch 114/200
#  - 0s - loss: 0.0567 - val_loss: 0.0195
# Epoch 115/200
#  - 0s - loss: 0.0534 - val_loss: 0.0465
# Epoch 116/200
#  - 0s - loss: 0.0938 - val_loss: 0.0178
# Epoch 117/200
#  - 0s - loss: 0.0459 - val_loss: 0.0205
# Epoch 118/200
#  - 0s - loss: 0.0558 - val_loss: 0.0282
# Epoch 119/200
#  - 0s - loss: 0.0387 - val_loss: 0.0499
# Epoch 120/200
#  - 0s - loss: 0.0440 - val_loss: 0.0127
# Epoch 121/200
#  - 0s - loss: 0.0471 - val_loss: 0.0237
# Epoch 122/200
#  - 0s - loss: 0.0528 - val_loss: 0.0237
# Epoch 123/200
#  - 0s - loss: 0.0404 - val_loss: 0.0132
# Epoch 124/200
#  - 0s - loss: 0.0539 - val_loss: 0.0174
# Epoch 125/200
#  - 0s - loss: 0.0453 - val_loss: 0.0159
# Epoch 126/200
#  - 0s - loss: 0.0510 - val_loss: 0.0122
# Epoch 127/200
#  - 0s - loss: 0.0388 - val_loss: 0.0169
# Epoch 128/200
#  - 0s - loss: 0.0500 - val_loss: 0.0241
# Epoch 129/200
#  - 0s - loss: 0.0497 - val_loss: 0.0481
# Epoch 130/200
#  - 0s - loss: 0.0664 - val_loss: 0.0274
# Epoch 131/200
#  - 0s - loss: 0.0452 - val_loss: 0.0374
# Epoch 132/200
#  - 0s - loss: 0.0587 - val_loss: 0.0249
# Epoch 133/200
#  - 0s - loss: 0.0528 - val_loss: 0.0461
# Epoch 134/200
#  - 0s - loss: 0.0864 - val_loss: 0.0176
# Epoch 135/200
#  - 0s - loss: 0.0523 - val_loss: 0.0374
# Epoch 136/200
#  - 0s - loss: 0.0496 - val_loss: 0.0161
# Epoch 137/200
#  - 0s - loss: 0.0449 - val_loss: 0.0397
# Epoch 138/200
#  - 0s - loss: 0.0412 - val_loss: 0.0185
# Epoch 139/200
#  - 0s - loss: 0.0389 - val_loss: 0.0343
# Epoch 140/200
#  - 0s - loss: 0.0431 - val_loss: 0.0101
# Epoch 141/200
#  - 0s - loss: 0.0378 - val_loss: 0.0161
# Epoch 142/200
#  - 0s - loss: 0.0587 - val_loss: 0.0049
# Epoch 143/200
#  - 0s - loss: 0.0376 - val_loss: 0.0107
# Epoch 144/200
#  - 0s - loss: 0.0524 - val_loss: 0.0042
# Epoch 145/200
#  - 0s - loss: 0.0485 - val_loss: 0.0136
# Epoch 146/200
#  - 0s - loss: 0.0591 - val_loss: 0.0108
# Epoch 147/200
#  - 0s - loss: 0.0440 - val_loss: 0.0206
# Epoch 148/200
#  - 0s - loss: 0.0346 - val_loss: 0.0086
# Epoch 149/200
#  - 0s - loss: 0.0322 - val_loss: 0.0248
# Epoch 150/200
#  - 0s - loss: 0.0343 - val_loss: 0.0072
# Epoch 151/200
#  - 0s - loss: 0.0229 - val_loss: 0.0102
# Epoch 152/200
#  - 0s - loss: 0.0292 - val_loss: 0.0113
# Epoch 153/200
#  - 0s - loss: 0.0285 - val_loss: 0.0113
# Epoch 154/200
#  - 0s - loss: 0.0269 - val_loss: 0.0038
# Epoch 155/200
#  - 0s - loss: 0.0242 - val_loss: 0.0105
# Epoch 156/200
#  - 0s - loss: 0.0254 - val_loss: 0.0033
# Epoch 157/200
#  - 0s - loss: 0.0269 - val_loss: 0.0125
# Epoch 158/200
#  - 0s - loss: 0.0388 - val_loss: 0.0031
# Epoch 159/200
#  - 0s - loss: 0.0666 - val_loss: 0.0016
# Epoch 160/200
#  - 0s - loss: 0.0481 - val_loss: 0.0024
# Epoch 161/200
#  - 0s - loss: 0.0701 - val_loss: 0.0069
# Epoch 162/200
#  - 0s - loss: 0.0517 - val_loss: 0.0515
# Epoch 163/200
#  - 0s - loss: 0.0822 - val_loss: 0.0319
# Epoch 164/200
#  - 0s - loss: 0.0630 - val_loss: 0.0796
# Epoch 165/200
#  - 0s - loss: 0.1149 - val_loss: 0.0382
# Epoch 166/200
#  - 0s - loss: 0.0837 - val_loss: 0.0919
# Epoch 167/200
#  - 0s - loss: 0.1752 - val_loss: 0.0033
# Epoch 168/200
#  - 0s - loss: 0.1624 - val_loss: 0.1554
# Epoch 169/200
#  - 0s - loss: 0.4254 - val_loss: 0.0287
# Epoch 170/200
#  - 0s - loss: 0.0832 - val_loss: 0.0998
# Epoch 171/200
#  - 0s - loss: 0.2615 - val_loss: 0.1373
# Epoch 172/200
#  - 0s - loss: 0.4123 - val_loss: 0.7393
# Epoch 173/200
#  - 0s - loss: 0.7147 - val_loss: 0.0224
# Epoch 174/200
#  - 0s - loss: 0.1269 - val_loss: 0.1286
# Epoch 175/200
#  - 0s - loss: 1.4125 - val_loss: 0.5873
# Epoch 176/200
#  - 0s - loss: 0.9730 - val_loss: 0.0129
# Epoch 177/200
#  - 0s - loss: 0.1595 - val_loss: 0.2754
# Epoch 178/200
#  - 0s - loss: 0.2584 - val_loss: 0.1192
# Epoch 179/200
#  - 0s - loss: 0.0504 - val_loss: 0.0331
# Epoch 180/200
#  - 0s - loss: 0.0757 - val_loss: 0.0134
# Epoch 181/200
#  - 0s - loss: 0.1126 - val_loss: 0.0440
# Epoch 182/200
#  - 0s - loss: 0.0605 - val_loss: 0.0209
# Epoch 183/200
#  - 0s - loss: 0.0485 - val_loss: 0.0204
# Epoch 184/200
#  - 0s - loss: 0.0490 - val_loss: 0.0264
# Epoch 185/200
#  - 0s - loss: 0.0408 - val_loss: 0.0066
# Epoch 186/200
#  - 0s - loss: 0.0568 - val_loss: 0.0238
# Epoch 187/200
#  - 0s - loss: 0.0557 - val_loss: 0.0150
# Epoch 188/200
#  - 0s - loss: 0.0896 - val_loss: 0.0188
# Epoch 189/200
#  - 0s - loss: 0.0484 - val_loss: 0.0047
# Epoch 190/200
#  - 0s - loss: 0.0469 - val_loss: 0.0244
# Epoch 191/200
#  - 0s - loss: 0.0389 - val_loss: 0.0064
# Epoch 192/200
#  - 0s - loss: 0.0349 - val_loss: 0.0114
# Epoch 193/200
#  - 0s - loss: 0.0270 - val_loss: 0.0032
# Epoch 194/200
#  - 0s - loss: 0.0261 - val_loss: 0.0028
# Epoch 195/200
#  - 0s - loss: 0.0224 - val_loss: 0.0011
# Epoch 196/200
#  - 0s - loss: 0.0279 - val_loss: 0.0031
# Epoch 197/200
#  - 0s - loss: 0.0258 - val_loss: 0.0030
# Epoch 198/200
#  - 0s - loss: 0.0291 - val_loss: 0.0011
# Epoch 199/200
#  - 0s - loss: 0.0332 - val_loss: 9.4358e-04
# Epoch 200/200
#  - 0s - loss: 0.0270 - val_loss: 0.0015

# %%
res_2 = make_rolling_window(LSTM_model_daily_2, train_X, train_y, val_X, val_y, batch_size = 32, epochs = 2)
# Out:
# Train on 500 samples, validate on 1 samples
# Epoch 1/2
#  - 2s - loss: 0.0248 - val_loss: 9.7547e-05
# Epoch 2/2
#  - 0s - loss: 0.0270 - val_loss: 8.6474e-05
# Train on 501 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0278 - val_loss: 1.5940e-04
# Epoch 2/2
#  - 0s - loss: 0.0301 - val_loss: 8.1111e-04
# Train on 502 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0296 - val_loss: 7.7227e-05
# Epoch 2/2
#  - 0s - loss: 0.0296 - val_loss: 0.0121
# Train on 503 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0331 - val_loss: 3.5895e-04
# Epoch 2/2
#  - 0s - loss: 0.0288 - val_loss: 0.0302
# Train on 504 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0340 - val_loss: 0.0061
# Epoch 2/2
#  - 0s - loss: 0.0281 - val_loss: 0.0125
# Train on 505 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0338 - val_loss: 1.1766e-04
# Epoch 2/2
#  - 0s - loss: 0.0330 - val_loss: 0.0606
# Train on 506 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0437 - val_loss: 0.0358
# Epoch 2/2
#  - 0s - loss: 0.0496 - val_loss: 0.0519
# Train on 507 samples, validate on 1 samples
# Epoch 1/2
#  - 4s - loss: 0.0769 - val_loss: 0.0175
# Epoch 2/2
#  - 0s - loss: 0.0507 - val_loss: 0.0530
# Train on 508 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0590 - val_loss: 0.0268
# Epoch 2/2
#  - 0s - loss: 0.0367 - val_loss: 0.0130
# Train on 509 samples, validate on 1 samples
# Epoch 1/2
#  - 4s - loss: 0.0399 - val_loss: 0.0017
# Epoch 2/2
#  - 0s - loss: 0.0312 - val_loss: 0.0124

# %%
predicts_2 = scaler.inverse_transform(np.array(res_2[0]))
actuals_2 = scaler.inverse_transform(np.array(res_2[1]))
rmse = math.sqrt(mean_squared_error(predicts_2, actuals_2))
print('Validation RMSE: %.3f' % rmse)
# Out:
# Validation RMSE: 515.363

# %%
res_test_2 = make_rolling_window(LSTM_model_daily_2, train_and_val_X, train_and_val_y, test_X, test_y, batch_size = 32, epochs = 2)
# Out:
# Train on 511 samples, validate on 1 samples
# Epoch 1/2
#  - 1s - loss: 0.0321 - val_loss: 0.0027
# Epoch 2/2
#  - 0s - loss: 0.0240 - val_loss: 0.0342
# Train on 512 samples, validate on 1 samples
# Epoch 1/2
#  - 0s - loss: 0.0253 - val_loss: 0.0034
# Epoch 2/2
#  - 0s - loss: 0.0229 - val_loss: 0.0144
# Train on 513 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0223 - val_loss: 2.2793e-04
# Epoch 2/2
#  - 0s - loss: 0.0311 - val_loss: 0.0129
# Train on 514 samples, validate on 1 samples
# Epoch 1/2
#  - 2s - loss: 0.0217 - val_loss: 0.0015
# Epoch 2/2
#  - 0s - loss: 0.0257 - val_loss: 0.0204
# Train on 515 samples, validate on 1 samples
# Epoch 1/2
#  - 2s - loss: 0.0298 - val_loss: 4.7395e-04
# Epoch 2/2
#  - 0s - loss: 0.0675 - val_loss: 0.0054
# Train on 516 samples, validate on 1 samples
# Epoch 1/2
#  - 2s - loss: 0.0487 - val_loss: 0.0126
# Epoch 2/2
#  - 0s - loss: 0.0566 - val_loss: 0.0038
# Train on 517 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0478 - val_loss: 0.0974
# Epoch 2/2
#  - 0s - loss: 0.0540 - val_loss: 0.0513
# Train on 518 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0381 - val_loss: 0.1201
# Epoch 2/2
#  - 0s - loss: 0.0456 - val_loss: 0.0144
# Train on 519 samples, validate on 1 samples
# Epoch 1/2
#  - 3s - loss: 0.0386 - val_loss: 0.1082
# Epoch 2/2
#  - 0s - loss: 0.0418 - val_loss: 0.0070

# %%
predicts_2 = scaler.inverse_transform(np.array(res_test_2[0]))
actuals_2 = scaler.inverse_transform(np.array(res_test_2[1]))
rmse = math.sqrt(mean_squared_error(predicts_2, actuals_2))
print('TEST RMSE: %.3f' % rmse)
# Out:
# TEST RMSE: 442.742
